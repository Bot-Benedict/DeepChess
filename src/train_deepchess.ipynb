# %% [markdown]
# # Notes
# * Shared Weights (Pos2Vec)
# * Learning rate 0.01 * 0.99 after each epoch
# * 1000 Epochs
# * 1,000,000 W - 1,000,000 L. Total 1,000,000 pairs.

# %%
import os
import tensorflow as tf
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Concatenate
from datetime import datetime
import numpy as np
import pandas as pd

import gc
from tensorflow.keras import backend as k

# %%
NUM_EPOCHS = 1000

# %%
def reset_random_seeds():
    '''
    Sets all necessary seed for reproduceability.
    '''
    os.environ['PYTHONHASHSEED']=str(1)
    tf.random.set_seed(1)
    np.random.seed(1)
    
reset_random_seeds()

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # Batch Creation

# %%
# Est 2mins 45secs
# win = np.load('../data/win_loss/win.npy')
# loss = np.load('../data/win_loss/loss.npy')
# win = win[:3000000]
# loss = loss[:3000000]
# np.save('../data/win_loss/win_3mil.npy', win)
# np.save('../data/win_loss/loss_3mil.npy', loss)

# # Est 2mins
# # Reduced size of wins and losses due to memory constraint
# win = np.load('../data/win_loss/win_3mil.npy')
# loss = np.load('../data/win_loss/loss_3mil.npy')

# Est 1min 20sec
# Reduced size of wins and losses to Deep Chess's due to memory constraint.
# win = win[:2216950]
# loss = loss[:1643870]
# np.save('../data/win_loss/win_deepchess.npy', win)
# np.save('../data/win_loss/loss_deepchess.npy', loss)
win = np.load('../data/win_loss/win_deepchess.npy')
loss = np.load('../data/win_loss/loss_deepchess.npy')

# %%
len(win), len(loss)
# Out:
# (2216950, 1643870)

# %%
model = Sequential([
    Dense(773,activation='relu'),
    Dense(600,activation='relu'),
    Dense(400,activation='relu'),
    Dense(200,activation='relu'),
    Dense(100,activation='relu')
])
model.load_weights('../models/fpos2vec_v1/fpos2vec_v1')

# %%
left_input = Input((None, 773))
right_input = Input((None, 773))
encoded_l = model(left_input)
encoded_r = model(right_input)

# %%
concatenated = Concatenate()([encoded_l, encoded_r])
deepchess = Dense(400, activation='relu')(concatenated)
deepchess = Dense(200, activation='relu')(deepchess)
deepchess = Dense(100, activation='relu')(deepchess)
deepchess_output = Dense(2, activation='softmax')(deepchess)

deepchess_model = Model(inputs=[left_input, right_input], outputs=deepchess_output)
deepchess_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss=tf.keras.losses.binary_crossentropy, metrics=['acc']) #, run_eagerly=True)

# %%
def scheduler(epoch, lr):
    return lr*0.99
reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
class ClearMemory(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        k.clear_session()

# %%
def get_train_data(train_size=1000000):
    # Get wins and losses
    w_selection = np.random.choice(win.shape[0], train_size, replace=False)
    w = win[w_selection]
    l_selection = np.random.choice(loss.shape[0], train_size, replace=False)
    l = loss[l_selection]

    # Get entire dataframe (1.2million rows)
    df = pd.DataFrame(data=[(w[i], l[i], np.array([1,0]).astype('uint8')) for i in range(train_size)],columns=['x_left', 'x_right', 'y'])

    # Find random rows where we swap win/loss to loss/win
    idx = np.random.rand(len(df)) < 0.5
    # Update swapped rows
    df.loc[idx, ['x_left', 'x_right']] = df.loc[idx, ['x_right', 'x_left']].to_numpy()
    # x_val_left, x_val_right, y_val
    return np.array(df.x_left.to_list())[:, np.newaxis, :], np.array(df.x_right.to_list())[:, np.newaxis, :], np.array([(np.array([0,1]).astype('uint8')) if i else (np.array([1,0]).astype('uint8')) for i in idx])[:, np.newaxis, :]

# %%
def get_val_data(test_size=200000):
    # Get wins and losses
    w_selection = np.random.choice(win.shape[0], test_size, replace=False)
    w = win[w_selection]
    l_selection = np.random.choice(loss.shape[0], test_size, replace=False)
    l = loss[l_selection]

    # Get entire dataframe (1.2million rows)
    df = pd.DataFrame(data=[(w[i], l[i], np.array([1,0]).astype('uint8')) for i in range(test_size)],columns=['x_left', 'x_right', 'y'])

    # Find random rows where we swap win/loss to loss/win
    idx = np.random.rand(len(df)) < 0.5
    # Update swapped rows
    df.loc[idx, ['x_left', 'x_right']] = df.loc[idx, ['x_right', 'x_left']].to_numpy()
    # x_val_left, x_val_right, y_val
    return np.array(df.x_left.to_list())[:, np.newaxis, :], np.array(df.x_right.to_list())[:, np.newaxis, :], np.array([(np.array([0,1]).astype('uint8')) if i else (np.array([1,0]).astype('uint8')) for i in idx])[:, np.newaxis, :]


    # w = win[np.random.choice(win.shape[0], test_size, replace=False)]
    # # l_selection = np.random.choice(loss.shape[0], train_size, replace=False)
    # l = loss[np.random.choice(loss.shape[0], test_size, replace=False)]
    # y = np.array([[1,0]]*len(w)).astype('uint8')
    # for i,_ in enumerate(np.random.rand(len(w)) < 0.5):
    #     w[i], l[i] = l[i], w[i]
    #     y[i] = [0,1]
    # return w[:, np.newaxis, :], l[:, np.newaxis, :], y[:, np.newaxis, :]

# %%
periodic_save = tf.keras.callbacks.ModelCheckpoint(filepath='../models/deepchess/deepchess', verbose=0,
                    save_best_only=True, monitor='val_acc', mode='max', save_weights_only=False)

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(
        self, 
        x_left,
        x_right,
        y,
        batch_size=50000, 
        num_classes=None,
    ):
        self.x_left = x_left
        self.x_right = x_right
        self.y = y
        self.batch_size = batch_size
        self.num_classes = num_classes
        
    def __len__(self):
        # Denotes the number of batches per epoch
        return len(self.y) // self.batch_size

    def __getitem__(self, index):
        return (self.x_left[index*self.batch_size:(index+1)*self.batch_size], self.x_right[index*self.batch_size:(index+1)*self.batch_size]), self.y[index*self.batch_size:(index+1)*self.batch_size]

# %%
history = []
for epoch in range(NUM_EPOCHS):
    print(f'Epoch {epoch}: {datetime.now().strftime("%d/%m/%Y %H:%M:%S")} | ', end='')
    x_train_left, x_train_right, y_train = get_train_data()
    x_val_left, x_val_right, y_val = get_val_data()
    
    train_datagen = DataGenerator(x_train_left, x_train_right, y_train)
    val_datagen = DataGenerator(x_val_left, x_val_right, y_val, batch_size=25000)
    
    deepchess_model.fit(x=train_datagen, callbacks=[reduce_lr, ClearMemory(), periodic_save], validation_data=val_datagen, verbose=0, max_queue_size=1)
    
    history.append(deepchess_model.history.history)
    print(f'{datetime.now().strftime("%d/%m/%Y %H:%M:%S")}: {deepchess_model.history.history}')
# Out:
# Epoch 0: 25/10/2021 04:17:27 | WARNING:tensorflow:From C:\Users\lowbe\Anaconda3\envs\fyp\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\lowbe\Anaconda3\envs\fyp\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:17:56: {'loss': [0.7619384527206421], 'acc': [0.5582860112190247], 'val_loss': [0.5744996666908264], 'val_acc': [0.6994749903678894], 'lr': [0.0099]}
# Epoch 1: 25/10/2021 04:17:56 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:18:22: {'loss': [0.5092024207115173], 'acc': [0.7399420142173767], 'val_loss': [0.4690490961074829], 'val_acc': [0.7646600008010864], 'lr': [0.009801]}
# Epoch 2: 25/10/2021 04:18:22 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:18:49: {'loss': [0.42470428347587585], 'acc': [0.7907509803771973], 'val_loss': [0.36599308252334595], 'val_acc': [0.8244400024414062], 'lr': [0.009702991]}
# Epoch 3: 25/10/2021 04:18:49 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:19:14: {'loss': [0.39397862553596497], 'acc': [0.8086730241775513], 'val_loss': [0.3458794057369232], 'val_acc': [0.8346350193023682], 'lr': [0.009605961]}
# Epoch 4: 25/10/2021 04:19:14 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:19:40: {'loss': [0.3327915668487549], 'acc': [0.8410000205039978], 'val_loss': [0.3152399957180023], 'val_acc': [0.8507400155067444], 'lr': [0.0095099015]}
# Epoch 5: 25/10/2021 04:19:40 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:20:07: {'loss': [0.308666855096817], 'acc': [0.8547520041465759], 'val_loss': [0.29562434554100037], 'val_acc': [0.8621399998664856], 'lr': [0.009414802]}
# Epoch 6: 25/10/2021 04:20:07 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:20:34: {'loss': [0.29512670636177063], 'acc': [0.8617640137672424], 'val_loss': [0.28806328773498535], 'val_acc': [0.8653150200843811], 'lr': [0.009320654]}
# Epoch 7: 25/10/2021 04:20:34 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:21:03: {'loss': [0.2854798138141632], 'acc': [0.8664169907569885], 'val_loss': [0.27608492970466614], 'val_acc': [0.8714500069618225], 'lr': [0.009227447]}
# Epoch 8: 25/10/2021 04:21:03 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:21:29: {'loss': [0.2743147015571594], 'acc': [0.8721939921379089], 'val_loss': [0.2664659321308136], 'val_acc': [0.8772850036621094], 'lr': [0.009135173]}
# Epoch 9: 25/10/2021 04:21:29 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:21:54: {'loss': [0.2663576006889343], 'acc': [0.8761619925498962], 'val_loss': [0.2578471601009369], 'val_acc': [0.8803449869155884], 'lr': [0.009043821]}
# Epoch 10: 25/10/2021 04:21:54 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:22:20: {'loss': [0.26025402545928955], 'acc': [0.8795179724693298], 'val_loss': [0.25361883640289307], 'val_acc': [0.882794976234436], 'lr': [0.008953383]}
# Epoch 11: 25/10/2021 04:22:20 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:22:46: {'loss': [0.25432929396629333], 'acc': [0.881837010383606], 'val_loss': [0.2452961504459381], 'val_acc': [0.8872500061988831], 'lr': [0.00886385]}
# Epoch 12: 25/10/2021 04:22:46 | 25/10/2021 04:23:06: {'loss': [0.2492900937795639], 'acc': [0.8845909833908081], 'val_loss': [0.2454763501882553], 'val_acc': [0.8857399821281433], 'lr': [0.008775211]}
# Epoch 13: 25/10/2021 04:23:06 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:23:31: {'loss': [0.24439623951911926], 'acc': [0.8870739936828613], 'val_loss': [0.23527304828166962], 'val_acc': [0.8919749855995178], 'lr': [0.008687459]}
# Epoch 14: 25/10/2021 04:23:31 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:23:57: {'loss': [0.2384769320487976], 'acc': [0.8896870017051697], 'val_loss': [0.22953394055366516], 'val_acc': [0.8946849703788757], 'lr': [0.008600584]}
# Epoch 15: 25/10/2021 04:23:57 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:24:22: {'loss': [0.2324260026216507], 'acc': [0.8927729725837708], 'val_loss': [0.22734439373016357], 'val_acc': [0.895704984664917], 'lr': [0.008514578]}
# Epoch 16: 25/10/2021 04:24:22 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:24:47: {'loss': [0.22929593920707703], 'acc': [0.8944439888000488], 'val_loss': [0.22123293578624725], 'val_acc': [0.8977699875831604], 'lr': [0.008429432]}
# Epoch 17: 25/10/2021 04:24:47 | 25/10/2021 04:25:07: {'loss': [0.22451643645763397], 'acc': [0.8966709971427917], 'val_loss': [0.22202809154987335], 'val_acc': [0.897379994392395], 'lr': [0.008345138]}
# Epoch 18: 25/10/2021 04:25:07 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:25:34: {'loss': [0.22087785601615906], 'acc': [0.8981620073318481], 'val_loss': [0.21419842541217804], 'val_acc': [0.9012200236320496], 'lr': [0.008261687]}
# Epoch 19: 25/10/2021 04:25:34 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:26:01: {'loss': [0.21643808484077454], 'acc': [0.9004290103912354], 'val_loss': [0.21002750098705292], 'val_acc': [0.9044299721717834], 'lr': [0.00817907]}
# Epoch 20: 25/10/2021 04:26:01 | 25/10/2021 04:26:21: {'loss': [0.21483634412288666], 'acc': [0.9007300138473511], 'val_loss': [0.20753781497478485], 'val_acc': [0.9042900204658508], 'lr': [0.00809728]}
# Epoch 21: 25/10/2021 04:26:21 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:26:47: {'loss': [0.20840881764888763], 'acc': [0.9035800099372864], 'val_loss': [0.20388264954090118], 'val_acc': [0.9063500165939331], 'lr': [0.008016307]}
# Epoch 22: 25/10/2021 04:26:47 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:27:13: {'loss': [0.20795585215091705], 'acc': [0.9037969708442688], 'val_loss': [0.1996123492717743], 'val_acc': [0.9080749750137329], 'lr': [0.007936144]}
# Epoch 23: 25/10/2021 04:27:13 | 25/10/2021 04:27:33: {'loss': [0.20151366293430328], 'acc': [0.9064120054244995], 'val_loss': [0.20209267735481262], 'val_acc': [0.9068650007247925], 'lr': [0.0078567825]}
# Epoch 24: 25/10/2021 04:27:33 | 25/10/2021 04:27:53: {'loss': [0.20207546651363373], 'acc': [0.9063969850540161], 'val_loss': [0.19868367910385132], 'val_acc': [0.9076650142669678], 'lr': [0.0077782148]}
# Epoch 25: 25/10/2021 04:27:53 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:28:18: {'loss': [0.19807615876197815], 'acc': [0.9082009792327881], 'val_loss': [0.19315525889396667], 'val_acc': [0.910610020160675], 'lr': [0.0077004326]}
# Epoch 26: 25/10/2021 04:28:18 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:28:43: {'loss': [0.19278988242149353], 'acc': [0.9108459949493408], 'val_loss': [0.18604426085948944], 'val_acc': [0.9139999747276306], 'lr': [0.007623428]}
# Epoch 27: 25/10/2021 04:28:43 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:29:10: {'loss': [0.19005940854549408], 'acc': [0.9121170043945312], 'val_loss': [0.1859615445137024], 'val_acc': [0.9140849709510803], 'lr': [0.0075471937]}
# Epoch 28: 25/10/2021 04:29:10 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:29:35: {'loss': [0.187493696808815], 'acc': [0.913536012172699], 'val_loss': [0.18310077488422394], 'val_acc': [0.9151149988174438], 'lr': [0.0074717216]}
# Epoch 29: 25/10/2021 04:29:35 | 25/10/2021 04:29:56: {'loss': [0.18547500669956207], 'acc': [0.9140939712524414], 'val_loss': [0.18515440821647644], 'val_acc': [0.91423499584198], 'lr': [0.0073970044]}
# Epoch 30: 25/10/2021 04:29:56 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:30:22: {'loss': [0.18417677283287048], 'acc': [0.9149029850959778], 'val_loss': [0.18049156665802002], 'val_acc': [0.9152250289916992], 'lr': [0.0073230346]}
# Epoch 31: 25/10/2021 04:30:22 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:30:49: {'loss': [0.18151676654815674], 'acc': [0.915814995765686], 'val_loss': [0.1769581288099289], 'val_acc': [0.9179450273513794], 'lr': [0.007249804]}
# Epoch 32: 25/10/2021 04:30:49 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:31:15: {'loss': [0.1806395947933197], 'acc': [0.9160630106925964], 'val_loss': [0.17462579905986786], 'val_acc': [0.9192299842834473], 'lr': [0.0071773063]}
# Epoch 33: 25/10/2021 04:31:15 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:31:42: {'loss': [0.1776336133480072], 'acc': [0.9175230264663696], 'val_loss': [0.17258843779563904], 'val_acc': [0.9199550151824951], 'lr': [0.0071055335]}
# Epoch 34: 25/10/2021 04:31:42 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:32:07: {'loss': [0.17627368867397308], 'acc': [0.9183520078659058], 'val_loss': [0.17101140320301056], 'val_acc': [0.9202049970626831], 'lr': [0.0070344782]}
# Epoch 35: 25/10/2021 04:32:07 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:32:34: {'loss': [0.1746073067188263], 'acc': [0.9188920259475708], 'val_loss': [0.1683417558670044], 'val_acc': [0.922914981842041], 'lr': [0.0069641336]}
# Epoch 36: 25/10/2021 04:32:34 | 25/10/2021 04:32:55: {'loss': [0.1722518354654312], 'acc': [0.9200950264930725], 'val_loss': [0.1732824742794037], 'val_acc': [0.9191750288009644], 'lr': [0.006894492]}
# Epoch 37: 25/10/2021 04:32:55 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:33:21: {'loss': [0.17155711352825165], 'acc': [0.9204530119895935], 'val_loss': [0.16592538356781006], 'val_acc': [0.9237350225448608], 'lr': [0.006825547]}
# Epoch 38: 25/10/2021 04:33:21 | 25/10/2021 04:33:41: {'loss': [0.16938140988349915], 'acc': [0.921347975730896], 'val_loss': [0.16647864878177643], 'val_acc': [0.9223150014877319], 'lr': [0.0067572915]}
# Epoch 39: 25/10/2021 04:33:41 | 25/10/2021 04:34:00: {'loss': [0.16735480725765228], 'acc': [0.9222339987754822], 'val_loss': [0.16650059819221497], 'val_acc': [0.923105001449585], 'lr': [0.0066897185]}
# Epoch 40: 25/10/2021 04:34:00 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:34:32: {'loss': [0.167399063706398], 'acc': [0.921763002872467], 'val_loss': [0.16145655512809753], 'val_acc': [0.9251199960708618], 'lr': [0.006622821]}
# Epoch 41: 25/10/2021 04:34:32 | 25/10/2021 04:34:54: {'loss': [0.16464805603027344], 'acc': [0.9234039783477783], 'val_loss': [0.16309553384780884], 'val_acc': [0.9247249960899353], 'lr': [0.006556593]}
# Epoch 42: 25/10/2021 04:34:54 | 25/10/2021 04:35:15: {'loss': [0.1627723127603531], 'acc': [0.9241470098495483], 'val_loss': [0.16363762319087982], 'val_acc': [0.9235950112342834], 'lr': [0.006491027]}
# Epoch 43: 25/10/2021 04:35:15 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:35:43: {'loss': [0.16131748259067535], 'acc': [0.924992024898529], 'val_loss': [0.16038823127746582], 'val_acc': [0.9255449771881104], 'lr': [0.0064261165]}
# Epoch 44: 25/10/2021 04:35:43 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:36:10: {'loss': [0.1604500263929367], 'acc': [0.9253219962120056], 'val_loss': [0.15812063217163086], 'val_acc': [0.9263799786567688], 'lr': [0.006361855]}
# Epoch 45: 25/10/2021 04:36:10 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:36:37: {'loss': [0.15744878351688385], 'acc': [0.9264540076255798], 'val_loss': [0.15608137845993042], 'val_acc': [0.9271849989891052], 'lr': [0.0062982365]}
# Epoch 46: 25/10/2021 04:36:37 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:37:03: {'loss': [0.1583002656698227], 'acc': [0.9262530207633972], 'val_loss': [0.15487851202487946], 'val_acc': [0.9274449944496155], 'lr': [0.006235254]}
# Epoch 47: 25/10/2021 04:37:03 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:37:30: {'loss': [0.15582337975502014], 'acc': [0.9275320172309875], 'val_loss': [0.15102365612983704], 'val_acc': [0.9299700260162354], 'lr': [0.0061729015]}
# Epoch 48: 25/10/2021 04:37:30 | 25/10/2021 04:37:50: {'loss': [0.15574879944324493], 'acc': [0.9275180101394653], 'val_loss': [0.15270793437957764], 'val_acc': [0.9287499785423279], 'lr': [0.0061111725]}
# Epoch 49: 25/10/2021 04:37:50 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:38:15: {'loss': [0.15329132974147797], 'acc': [0.9286620020866394], 'val_loss': [0.14995554089546204], 'val_acc': [0.9305049777030945], 'lr': [0.006050061]}
# Epoch 50: 25/10/2021 04:38:15 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:38:41: {'loss': [0.1527760922908783], 'acc': [0.9288610219955444], 'val_loss': [0.14862914383411407], 'val_acc': [0.931725025177002], 'lr': [0.0059895604]}
# Epoch 51: 25/10/2021 04:38:41 | 25/10/2021 04:39:01: {'loss': [0.15127210319042206], 'acc': [0.9293689727783203], 'val_loss': [0.15238849818706512], 'val_acc': [0.9290900230407715], 'lr': [0.0059296647]}
# Epoch 52: 25/10/2021 04:39:01 | 25/10/2021 04:39:20: {'loss': [0.14983420073986053], 'acc': [0.9298020005226135], 'val_loss': [0.145865336060524], 'val_acc': [0.9316400289535522], 'lr': [0.005870368]}
# Epoch 53: 25/10/2021 04:39:20 | 25/10/2021 04:39:40: {'loss': [0.14936356246471405], 'acc': [0.9302099943161011], 'val_loss': [0.14597924053668976], 'val_acc': [0.9313799738883972], 'lr': [0.0058116643]}
# Epoch 54: 25/10/2021 04:39:40 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:40:05: {'loss': [0.1476207971572876], 'acc': [0.9308980107307434], 'val_loss': [0.1438053548336029], 'val_acc': [0.9326249957084656], 'lr': [0.0057535474]}
# Epoch 55: 25/10/2021 04:40:05 | 25/10/2021 04:40:25: {'loss': [0.14785116910934448], 'acc': [0.9311169981956482], 'val_loss': [0.14470408856868744], 'val_acc': [0.9320150017738342], 'lr': [0.005696012]}
# Epoch 56: 25/10/2021 04:40:25 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:40:50: {'loss': [0.14676353335380554], 'acc': [0.931210994720459], 'val_loss': [0.1436460018157959], 'val_acc': [0.9332349896430969], 'lr': [0.005639052]}
# Epoch 57: 25/10/2021 04:40:50 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:41:17: {'loss': [0.1454176902770996], 'acc': [0.9321969747543335], 'val_loss': [0.1421891748905182], 'val_acc': [0.9333800077438354], 'lr': [0.0055826614]}
# Epoch 58: 25/10/2021 04:41:17 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:41:43: {'loss': [0.14549265801906586], 'acc': [0.9319109916687012], 'val_loss': [0.14131595194339752], 'val_acc': [0.9339249730110168], 'lr': [0.0055268346]}
# Epoch 59: 25/10/2021 04:41:43 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:42:09: {'loss': [0.14453409612178802], 'acc': [0.9322929978370667], 'val_loss': [0.14085523784160614], 'val_acc': [0.9344199895858765], 'lr': [0.005471566]}
# Epoch 60: 25/10/2021 04:42:09 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:42:35: {'loss': [0.14144566655158997], 'acc': [0.9337249994277954], 'val_loss': [0.13948415219783783], 'val_acc': [0.9345499873161316], 'lr': [0.0054168506]}
# Epoch 61: 25/10/2021 04:42:35 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:43:01: {'loss': [0.14168094098567963], 'acc': [0.9334530234336853], 'val_loss': [0.1395973563194275], 'val_acc': [0.9345899820327759], 'lr': [0.005362682]}
# Epoch 62: 25/10/2021 04:43:01 | 25/10/2021 04:43:21: {'loss': [0.14148956537246704], 'acc': [0.9336400032043457], 'val_loss': [0.14107756316661835], 'val_acc': [0.9339550137519836], 'lr': [0.005309055]}
# Epoch 63: 25/10/2021 04:43:21 | 25/10/2021 04:43:40: {'loss': [0.14136022329330444], 'acc': [0.9337990283966064], 'val_loss': [0.14024902880191803], 'val_acc': [0.9343000054359436], 'lr': [0.0052559646]}
# Epoch 64: 25/10/2021 04:43:40 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:44:06: {'loss': [0.14074447751045227], 'acc': [0.9340739846229553], 'val_loss': [0.13796666264533997], 'val_acc': [0.9352049827575684], 'lr': [0.005203405]}
# Epoch 65: 25/10/2021 04:44:06 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:44:32: {'loss': [0.14082030951976776], 'acc': [0.9338070154190063], 'val_loss': [0.13811972737312317], 'val_acc': [0.9357849955558777], 'lr': [0.005151371]}
# Epoch 66: 25/10/2021 04:44:32 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:44:58: {'loss': [0.13849776983261108], 'acc': [0.9348859786987305], 'val_loss': [0.13349081575870514], 'val_acc': [0.9378799796104431], 'lr': [0.005099857]}
# Epoch 67: 25/10/2021 04:44:58 | 25/10/2021 04:45:18: {'loss': [0.13632729649543762], 'acc': [0.9359139800071716], 'val_loss': [0.13376064598560333], 'val_acc': [0.937125027179718], 'lr': [0.0050488585]}
# Epoch 68: 25/10/2021 04:45:18 | 25/10/2021 04:45:37: {'loss': [0.13585349917411804], 'acc': [0.9362059831619263], 'val_loss': [0.13390909135341644], 'val_acc': [0.9370750188827515], 'lr': [0.00499837]}
# Epoch 69: 25/10/2021 04:45:37 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:46:03: {'loss': [0.13758395612239838], 'acc': [0.9354450106620789], 'val_loss': [0.13163703680038452], 'val_acc': [0.9385150074958801], 'lr': [0.0049483865]}
# Epoch 70: 25/10/2021 04:46:03 | 25/10/2021 04:46:23: {'loss': [0.1342753767967224], 'acc': [0.9371259808540344], 'val_loss': [0.13077126443386078], 'val_acc': [0.9384700059890747], 'lr': [0.0048989025]}
# Epoch 71: 25/10/2021 04:46:23 | 25/10/2021 04:46:42: {'loss': [0.1333732008934021], 'acc': [0.9373080134391785], 'val_loss': [0.13273555040359497], 'val_acc': [0.9374799728393555], 'lr': [0.0048499135]}
# Epoch 72: 25/10/2021 04:46:42 | 25/10/2021 04:47:01: {'loss': [0.13333478569984436], 'acc': [0.9375280141830444], 'val_loss': [0.1325886845588684], 'val_acc': [0.9378299713134766], 'lr': [0.0048014144]}
# Epoch 73: 25/10/2021 04:47:01 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:47:27: {'loss': [0.13298676908016205], 'acc': [0.9375579953193665], 'val_loss': [0.12924587726593018], 'val_acc': [0.9398750066757202], 'lr': [0.0047534]}
# Epoch 74: 25/10/2021 04:47:27 | 25/10/2021 04:47:47: {'loss': [0.1320095658302307], 'acc': [0.9377819895744324], 'val_loss': [0.12933339178562164], 'val_acc': [0.9395999908447266], 'lr': [0.0047058663]}
# Epoch 75: 25/10/2021 04:47:47 | 25/10/2021 04:48:06: {'loss': [0.13184699416160583], 'acc': [0.9377800226211548], 'val_loss': [0.13019444048404694], 'val_acc': [0.9386450052261353], 'lr': [0.0046588075]}
# Epoch 76: 25/10/2021 04:48:06 | 25/10/2021 04:48:26: {'loss': [0.131725013256073], 'acc': [0.9382010102272034], 'val_loss': [0.13510827720165253], 'val_acc': [0.9364650249481201], 'lr': [0.0046122195]}
# Epoch 77: 25/10/2021 04:48:26 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:48:52: {'loss': [0.12995170056819916], 'acc': [0.9390199780464172], 'val_loss': [0.1272701621055603], 'val_acc': [0.9403049945831299], 'lr': [0.004566097]}
# Epoch 78: 25/10/2021 04:48:52 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:49:18: {'loss': [0.1278516948223114], 'acc': [0.9397879838943481], 'val_loss': [0.12683874368667603], 'val_acc': [0.9404199719429016], 'lr': [0.0045204363]}
# Epoch 79: 25/10/2021 04:49:18 | 25/10/2021 04:49:39: {'loss': [0.1286495178937912], 'acc': [0.9392840266227722], 'val_loss': [0.126944899559021], 'val_acc': [0.9403349757194519], 'lr': [0.0044752317]}
# Epoch 80: 25/10/2021 04:49:39 | 25/10/2021 04:49:58: {'loss': [0.1288651078939438], 'acc': [0.9391989707946777], 'val_loss': [0.1266707181930542], 'val_acc': [0.9401749968528748], 'lr': [0.0044304794]}
# Epoch 81: 25/10/2021 04:49:58 | 25/10/2021 04:50:17: {'loss': [0.12747065722942352], 'acc': [0.9399530291557312], 'val_loss': [0.12589260935783386], 'val_acc': [0.9401649832725525], 'lr': [0.0043861745]}
# Epoch 82: 25/10/2021 04:50:17 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:50:43: {'loss': [0.12653829157352448], 'acc': [0.9405800104141235], 'val_loss': [0.12396746873855591], 'val_acc': [0.9422600269317627], 'lr': [0.004342313]}
# Epoch 83: 25/10/2021 04:50:43 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:51:09: {'loss': [0.12763823568820953], 'acc': [0.9401260018348694], 'val_loss': [0.12301589548587799], 'val_acc': [0.9426699876785278], 'lr': [0.00429889]}
# Epoch 84: 25/10/2021 04:51:09 | 25/10/2021 04:51:29: {'loss': [0.126926988363266], 'acc': [0.9402499794960022], 'val_loss': [0.1223854199051857], 'val_acc': [0.9423850178718567], 'lr': [0.004255901]}
# Epoch 85: 25/10/2021 04:51:29 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:51:55: {'loss': [0.12492778152227402], 'acc': [0.9411470293998718], 'val_loss': [0.12198297679424286], 'val_acc': [0.9427149891853333], 'lr': [0.004213342]}
# Epoch 86: 25/10/2021 04:51:55 | 25/10/2021 04:52:16: {'loss': [0.1242569237947464], 'acc': [0.9413710236549377], 'val_loss': [0.12341073900461197], 'val_acc': [0.942205011844635], 'lr': [0.0041712085]}
# Epoch 87: 25/10/2021 04:52:16 | 25/10/2021 04:52:35: {'loss': [0.12651731073856354], 'acc': [0.9403809905052185], 'val_loss': [0.1222342774271965], 'val_acc': [0.9422450065612793], 'lr': [0.0041294964]}
# Epoch 88: 25/10/2021 04:52:35 | 25/10/2021 04:52:54: {'loss': [0.12339810281991959], 'acc': [0.9419220089912415], 'val_loss': [0.12175532430410385], 'val_acc': [0.9425600171089172], 'lr': [0.0040882016]}
# Epoch 89: 25/10/2021 04:52:54 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:53:21: {'loss': [0.12225291132926941], 'acc': [0.9425870180130005], 'val_loss': [0.12035328149795532], 'val_acc': [0.9436100125312805], 'lr': [0.0040473198]}
# Epoch 90: 25/10/2021 04:53:21 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:53:48: {'loss': [0.12337522208690643], 'acc': [0.9418920278549194], 'val_loss': [0.12011757493019104], 'val_acc': [0.9437599778175354], 'lr': [0.0040068463]}
# Epoch 91: 25/10/2021 04:53:48 | 25/10/2021 04:54:08: {'loss': [0.12195660173892975], 'acc': [0.9426310062408447], 'val_loss': [0.12253246456384659], 'val_acc': [0.9424449801445007], 'lr': [0.003966778]}
# Epoch 92: 25/10/2021 04:54:08 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:54:34: {'loss': [0.12163536250591278], 'acc': [0.9425079822540283], 'val_loss': [0.11948896199464798], 'val_acc': [0.9437649846076965], 'lr': [0.00392711]}
# Epoch 93: 25/10/2021 04:54:34 | 25/10/2021 04:54:54: {'loss': [0.12057469040155411], 'acc': [0.9430490136146545], 'val_loss': [0.1204124242067337], 'val_acc': [0.9431599974632263], 'lr': [0.0038878391]}
# Epoch 94: 25/10/2021 04:54:54 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:55:20: {'loss': [0.12136686593294144], 'acc': [0.9427329897880554], 'val_loss': [0.11724874377250671], 'val_acc': [0.9448249936103821], 'lr': [0.0038489609]}
# Epoch 95: 25/10/2021 04:55:20 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:55:47: {'loss': [0.11950453370809555], 'acc': [0.9437559843063354], 'val_loss': [0.11652977764606476], 'val_acc': [0.9452599883079529], 'lr': [0.0038104712]}
# Epoch 96: 25/10/2021 04:55:47 | 25/10/2021 04:56:07: {'loss': [0.12007984519004822], 'acc': [0.9433320164680481], 'val_loss': [0.11930150538682938], 'val_acc': [0.9439250230789185], 'lr': [0.0037723666]}
# Epoch 97: 25/10/2021 04:56:07 | 25/10/2021 04:56:26: {'loss': [0.11851310729980469], 'acc': [0.9441739916801453], 'val_loss': [0.11760890483856201], 'val_acc': [0.9441649913787842], 'lr': [0.0037346429]}
# Epoch 98: 25/10/2021 04:56:26 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:56:53: {'loss': [0.11808859556913376], 'acc': [0.9444109797477722], 'val_loss': [0.11576825380325317], 'val_acc': [0.9457299709320068], 'lr': [0.0036972964]}
# Epoch 99: 25/10/2021 04:56:53 | 25/10/2021 04:57:12: {'loss': [0.11762303858995438], 'acc': [0.9445340037345886], 'val_loss': [0.11698631197214127], 'val_acc': [0.9448850154876709], 'lr': [0.0036603233]}
# Epoch 100: 25/10/2021 04:57:12 | 25/10/2021 04:57:32: {'loss': [0.1188800036907196], 'acc': [0.9437509775161743], 'val_loss': [0.11742302775382996], 'val_acc': [0.9449999928474426], 'lr': [0.00362372]}
# Epoch 101: 25/10/2021 04:57:32 | 25/10/2021 04:57:51: {'loss': [0.11934669315814972], 'acc': [0.9436179995536804], 'val_loss': [0.11731982231140137], 'val_acc': [0.9448249936103821], 'lr': [0.0035874827]}
# Epoch 102: 25/10/2021 04:57:51 | 25/10/2021 04:58:11: {'loss': [0.116756871342659], 'acc': [0.9449489712715149], 'val_loss': [0.11490902304649353], 'val_acc': [0.9454249739646912], 'lr': [0.003551608]}
# Epoch 103: 25/10/2021 04:58:11 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 04:58:37: {'loss': [0.11610974371433258], 'acc': [0.9449049830436707], 'val_loss': [0.11312893778085709], 'val_acc': [0.9466050267219543], 'lr': [0.003516092]}
# Epoch 104: 25/10/2021 04:58:37 | 25/10/2021 04:58:57: {'loss': [0.11539556831121445], 'acc': [0.9452930092811584], 'val_loss': [0.11540591716766357], 'val_acc': [0.9460049867630005], 'lr': [0.003480931]}
# Epoch 105: 25/10/2021 04:58:57 | 25/10/2021 04:59:16: {'loss': [0.11501147598028183], 'acc': [0.9456120133399963], 'val_loss': [0.11269163340330124], 'val_acc': [0.9464349746704102], 'lr': [0.0034461217]}
# Epoch 106: 25/10/2021 04:59:16 | 25/10/2021 04:59:36: {'loss': [0.11459046602249146], 'acc': [0.9456319808959961], 'val_loss': [0.11305674910545349], 'val_acc': [0.9464100003242493], 'lr': [0.0034116604]}
# Epoch 107: 25/10/2021 04:59:36 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:00:01: {'loss': [0.11383520811796188], 'acc': [0.9461039900779724], 'val_loss': [0.11216297000646591], 'val_acc': [0.9471750259399414], 'lr': [0.0033775438]}
# Epoch 108: 25/10/2021 05:00:01 | 25/10/2021 05:00:22: {'loss': [0.11458522081375122], 'acc': [0.9458879828453064], 'val_loss': [0.1130787581205368], 'val_acc': [0.9467250108718872], 'lr': [0.0033437684]}
# Epoch 109: 25/10/2021 05:00:22 | 25/10/2021 05:00:41: {'loss': [0.11386410892009735], 'acc': [0.9459050297737122], 'val_loss': [0.11306783556938171], 'val_acc': [0.9464399814605713], 'lr': [0.0033103307]}
# Epoch 110: 25/10/2021 05:00:41 | 25/10/2021 05:01:01: {'loss': [0.11319205909967422], 'acc': [0.946349024772644], 'val_loss': [0.11191307753324509], 'val_acc': [0.9471499919891357], 'lr': [0.0032772273]}
# Epoch 111: 25/10/2021 05:01:01 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:01:27: {'loss': [0.11324650794267654], 'acc': [0.9463859796524048], 'val_loss': [0.11119773238897324], 'val_acc': [0.9476850032806396], 'lr': [0.003244455]}
# Epoch 112: 25/10/2021 05:01:27 | 25/10/2021 05:01:47: {'loss': [0.11442360281944275], 'acc': [0.9457250237464905], 'val_loss': [0.11361242085695267], 'val_acc': [0.946370005607605], 'lr': [0.0032120105]}
# Epoch 113: 25/10/2021 05:01:47 | 25/10/2021 05:02:06: {'loss': [0.11233887076377869], 'acc': [0.946835994720459], 'val_loss': [0.11099103838205338], 'val_acc': [0.9472200274467468], 'lr': [0.0031798903]}
# Epoch 114: 25/10/2021 05:02:06 | 25/10/2021 05:02:26: {'loss': [0.11119989305734634], 'acc': [0.9473410248756409], 'val_loss': [0.1113690659403801], 'val_acc': [0.9471750259399414], 'lr': [0.0031480915]}
# Epoch 115: 25/10/2021 05:02:26 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:02:51: {'loss': [0.1110607236623764], 'acc': [0.9471529722213745], 'val_loss': [0.11062041670084], 'val_acc': [0.947950005531311], 'lr': [0.0031166105]}
# Epoch 116: 25/10/2021 05:02:51 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:03:18: {'loss': [0.11121930927038193], 'acc': [0.9472820162773132], 'val_loss': [0.10910354554653168], 'val_acc': [0.9488400220870972], 'lr': [0.0030854444]}
# Epoch 117: 25/10/2021 05:03:18 | 25/10/2021 05:03:38: {'loss': [0.11046154797077179], 'acc': [0.9475079774856567], 'val_loss': [0.10857026278972626], 'val_acc': [0.9487599730491638], 'lr': [0.00305459]}
# Epoch 118: 25/10/2021 05:03:38 | 25/10/2021 05:03:57: {'loss': [0.11024027317762375], 'acc': [0.9476079940795898], 'val_loss': [0.10869180411100388], 'val_acc': [0.9484900236129761], 'lr': [0.003024044]}
# Epoch 119: 25/10/2021 05:03:57 | 25/10/2021 05:04:17: {'loss': [0.10991024971008301], 'acc': [0.9476889967918396], 'val_loss': [0.10966034978628159], 'val_acc': [0.9480299949645996], 'lr': [0.0029938035]}
# Epoch 120: 25/10/2021 05:04:17 | 25/10/2021 05:04:36: {'loss': [0.1095927357673645], 'acc': [0.9480630159378052], 'val_loss': [0.10936117172241211], 'val_acc': [0.9479600191116333], 'lr': [0.0029638654]}
# Epoch 121: 25/10/2021 05:04:36 | 25/10/2021 05:04:56: {'loss': [0.10998641699552536], 'acc': [0.9477459788322449], 'val_loss': [0.10869452357292175], 'val_acc': [0.9485099911689758], 'lr': [0.0029342268]}
# Epoch 122: 25/10/2021 05:04:56 | 25/10/2021 05:05:16: {'loss': [0.10877776145935059], 'acc': [0.9484429955482483], 'val_loss': [0.10778392851352692], 'val_acc': [0.9484099745750427], 'lr': [0.0029048845]}
# Epoch 123: 25/10/2021 05:05:16 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:05:42: {'loss': [0.10908368974924088], 'acc': [0.9482349753379822], 'val_loss': [0.10693496465682983], 'val_acc': [0.9488649964332581], 'lr': [0.0028758356]}
# Epoch 124: 25/10/2021 05:05:42 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:06:09: {'loss': [0.10784532874822617], 'acc': [0.9485870003700256], 'val_loss': [0.10715941339731216], 'val_acc': [0.9491750001907349], 'lr': [0.0028470773]}
# Epoch 125: 25/10/2021 05:06:09 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:06:35: {'loss': [0.10785344988107681], 'acc': [0.9487680196762085], 'val_loss': [0.10371949523687363], 'val_acc': [0.9508000016212463], 'lr': [0.0028186066]}
# Epoch 126: 25/10/2021 05:06:35 | 25/10/2021 05:06:55: {'loss': [0.10775662958621979], 'acc': [0.9490050077438354], 'val_loss': [0.10673028975725174], 'val_acc': [0.9494249820709229], 'lr': [0.0027904205]}
# Epoch 127: 25/10/2021 05:06:55 | 25/10/2021 05:07:15: {'loss': [0.10707374662160873], 'acc': [0.9491209983825684], 'val_loss': [0.10522018373012543], 'val_acc': [0.9503899812698364], 'lr': [0.0027625163]}
# Epoch 128: 25/10/2021 05:07:15 | 25/10/2021 05:07:34: {'loss': [0.10744955390691757], 'acc': [0.9487940073013306], 'val_loss': [0.10541548579931259], 'val_acc': [0.9504899978637695], 'lr': [0.0027348911]}
# Epoch 129: 25/10/2021 05:07:34 | 25/10/2021 05:07:55: {'loss': [0.10683342814445496], 'acc': [0.9491080045700073], 'val_loss': [0.10599593818187714], 'val_acc': [0.949524998664856], 'lr': [0.0027075422]}
# Epoch 130: 25/10/2021 05:07:55 | 25/10/2021 05:08:15: {'loss': [0.10602369159460068], 'acc': [0.9498760104179382], 'val_loss': [0.10516193509101868], 'val_acc': [0.9496650099754333], 'lr': [0.0026804667]}
# Epoch 131: 25/10/2021 05:08:15 | 25/10/2021 05:08:35: {'loss': [0.10607829689979553], 'acc': [0.9495260119438171], 'val_loss': [0.1051245629787445], 'val_acc': [0.9497699737548828], 'lr': [0.002653662]}
# Epoch 132: 25/10/2021 05:08:35 | 25/10/2021 05:08:54: {'loss': [0.10552443563938141], 'acc': [0.9498929977416992], 'val_loss': [0.10438577830791473], 'val_acc': [0.9503849744796753], 'lr': [0.0026271255]}
# Epoch 133: 25/10/2021 05:08:54 | 25/10/2021 05:09:14: {'loss': [0.10571998357772827], 'acc': [0.9498029947280884], 'val_loss': [0.10437573492527008], 'val_acc': [0.9502450227737427], 'lr': [0.0026008543]}
# Epoch 134: 25/10/2021 05:09:14 | 25/10/2021 05:09:33: {'loss': [0.10479290783405304], 'acc': [0.950177013874054], 'val_loss': [0.10462082177400589], 'val_acc': [0.9504150152206421], 'lr': [0.0025748457]}
# Epoch 135: 25/10/2021 05:09:33 | 25/10/2021 05:09:53: {'loss': [0.10540059208869934], 'acc': [0.949891984462738], 'val_loss': [0.10758413374423981], 'val_acc': [0.9488499760627747], 'lr': [0.0025490972]}
# Epoch 136: 25/10/2021 05:09:53 | 25/10/2021 05:10:12: {'loss': [0.10585059970617294], 'acc': [0.9495959877967834], 'val_loss': [0.10454294085502625], 'val_acc': [0.9508000016212463], 'lr': [0.0025236062]}
# Epoch 137: 25/10/2021 05:10:12 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:10:40: {'loss': [0.10350928455591202], 'acc': [0.9506629705429077], 'val_loss': [0.10256455838680267], 'val_acc': [0.9510700106620789], 'lr': [0.0024983701]}
# Epoch 138: 25/10/2021 05:10:40 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:11:07: {'loss': [0.10343953967094421], 'acc': [0.9506760239601135], 'val_loss': [0.10127049684524536], 'val_acc': [0.9523100256919861], 'lr': [0.0024733865]}
# Epoch 139: 25/10/2021 05:11:07 | 25/10/2021 05:11:27: {'loss': [0.10378269851207733], 'acc': [0.9505320191383362], 'val_loss': [0.10325627028942108], 'val_acc': [0.9508200287818909], 'lr': [0.0024486526]}
# Epoch 140: 25/10/2021 05:11:27 | 25/10/2021 05:11:46: {'loss': [0.10414410382509232], 'acc': [0.9503160119056702], 'val_loss': [0.10308637470006943], 'val_acc': [0.9506750106811523], 'lr': [0.002424166]}
# Epoch 141: 25/10/2021 05:11:46 | 25/10/2021 05:12:06: {'loss': [0.10283777117729187], 'acc': [0.9509680271148682], 'val_loss': [0.10206013917922974], 'val_acc': [0.9513649940490723], 'lr': [0.0023999244]}
# Epoch 142: 25/10/2021 05:12:06 | 25/10/2021 05:12:26: {'loss': [0.10257737338542938], 'acc': [0.9509379863739014], 'val_loss': [0.10099739581346512], 'val_acc': [0.9518550038337708], 'lr': [0.0023759252]}
# Epoch 143: 25/10/2021 05:12:26 | 25/10/2021 05:12:45: {'loss': [0.10173171758651733], 'acc': [0.9513540267944336], 'val_loss': [0.10200200974941254], 'val_acc': [0.9514099955558777], 'lr': [0.002352166]}
# Epoch 144: 25/10/2021 05:12:45 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:13:11: {'loss': [0.1022755578160286], 'acc': [0.9511809945106506], 'val_loss': [0.09962564706802368], 'val_acc': [0.9524999856948853], 'lr': [0.0023286443]}
# Epoch 145: 25/10/2021 05:13:11 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:13:38: {'loss': [0.10160094499588013], 'acc': [0.9516630172729492], 'val_loss': [0.10056475549936295], 'val_acc': [0.9526200294494629], 'lr': [0.0023053577]}
# Epoch 146: 25/10/2021 05:13:38 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:14:04: {'loss': [0.10129762440919876], 'acc': [0.9515119791030884], 'val_loss': [0.09988929331302643], 'val_acc': [0.9530749917030334], 'lr': [0.0022823042]}
# Epoch 147: 25/10/2021 05:14:04 | 25/10/2021 05:14:24: {'loss': [0.1016027182340622], 'acc': [0.9516429901123047], 'val_loss': [0.09990244358778], 'val_acc': [0.9523749947547913], 'lr': [0.0022594812]}
# Epoch 148: 25/10/2021 05:14:24 | 25/10/2021 05:14:43: {'loss': [0.10052205622196198], 'acc': [0.951885998249054], 'val_loss': [0.10094654560089111], 'val_acc': [0.9512850046157837], 'lr': [0.0022368864]}
# Epoch 149: 25/10/2021 05:14:43 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:15:09: {'loss': [0.10090062767267227], 'acc': [0.9518700242042542], 'val_loss': [0.09795571118593216], 'val_acc': [0.9534649848937988], 'lr': [0.0022145174]}
# Epoch 150: 25/10/2021 05:15:09 | 25/10/2021 05:15:29: {'loss': [0.09997808933258057], 'acc': [0.9522730112075806], 'val_loss': [0.10136406868696213], 'val_acc': [0.9512100219726562], 'lr': [0.0021923722]}
# Epoch 151: 25/10/2021 05:15:29 | 25/10/2021 05:15:48: {'loss': [0.09986259043216705], 'acc': [0.9524250030517578], 'val_loss': [0.09859337657690048], 'val_acc': [0.9531599879264832], 'lr': [0.0021704484]}
# Epoch 152: 25/10/2021 05:15:48 | 25/10/2021 05:16:08: {'loss': [0.09978757053613663], 'acc': [0.9524480104446411], 'val_loss': [0.1003514975309372], 'val_acc': [0.951894998550415], 'lr': [0.002148744]}
# Epoch 153: 25/10/2021 05:16:08 | 25/10/2021 05:16:27: {'loss': [0.10031890869140625], 'acc': [0.9522219896316528], 'val_loss': [0.09825044125318527], 'val_acc': [0.9532949924468994], 'lr': [0.0021272565]}
# Epoch 154: 25/10/2021 05:16:27 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:16:53: {'loss': [0.09890448302030563], 'acc': [0.9528629779815674], 'val_loss': [0.09737297147512436], 'val_acc': [0.9536899924278259], 'lr': [0.002105984]}
# Epoch 155: 25/10/2021 05:16:53 | 25/10/2021 05:17:14: {'loss': [0.09949561208486557], 'acc': [0.9523379802703857], 'val_loss': [0.09834278374910355], 'val_acc': [0.9531800150871277], 'lr': [0.0020849241]}
# Epoch 156: 25/10/2021 05:17:14 | 25/10/2021 05:17:33: {'loss': [0.09882909804582596], 'acc': [0.9527469873428345], 'val_loss': [0.09891907870769501], 'val_acc': [0.9528949856758118], 'lr': [0.0020640749]}
# Epoch 157: 25/10/2021 05:17:33 | 25/10/2021 05:17:52: {'loss': [0.09866192191839218], 'acc': [0.953050971031189], 'val_loss': [0.09766637533903122], 'val_acc': [0.9528149962425232], 'lr': [0.0020434342]}
# Epoch 158: 25/10/2021 05:17:52 | 25/10/2021 05:18:11: {'loss': [0.09856309741735458], 'acc': [0.9530320167541504], 'val_loss': [0.09739106148481369], 'val_acc': [0.9534850120544434], 'lr': [0.0020229998]}
# Epoch 159: 25/10/2021 05:18:11 | 25/10/2021 05:18:31: {'loss': [0.09762797504663467], 'acc': [0.9534969925880432], 'val_loss': [0.09704683721065521], 'val_acc': [0.9536250233650208], 'lr': [0.0020027698]}
# Epoch 160: 25/10/2021 05:18:31 | 25/10/2021 05:18:50: {'loss': [0.09810761362314224], 'acc': [0.9528819918632507], 'val_loss': [0.09882769733667374], 'val_acc': [0.952584981918335], 'lr': [0.0019827422]}
# Epoch 161: 25/10/2021 05:18:50 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:19:16: {'loss': [0.09816544502973557], 'acc': [0.9532769918441772], 'val_loss': [0.09623239189386368], 'val_acc': [0.9539999961853027], 'lr': [0.0019629148]}
# Epoch 162: 25/10/2021 05:19:16 | 25/10/2021 05:19:36: {'loss': [0.09775272011756897], 'acc': [0.953311026096344], 'val_loss': [0.09867432713508606], 'val_acc': [0.952530026435852], 'lr': [0.0019432857]}
# Epoch 163: 25/10/2021 05:19:36 | 25/10/2021 05:19:55: {'loss': [0.09800250083208084], 'acc': [0.9533029794692993], 'val_loss': [0.0978868380188942], 'val_acc': [0.952489972114563], 'lr': [0.0019238528]}
# Epoch 164: 25/10/2021 05:19:55 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:20:22: {'loss': [0.09716184437274933], 'acc': [0.9535130262374878], 'val_loss': [0.0957939550280571], 'val_acc': [0.9546949863433838], 'lr': [0.0019046143]}
# Epoch 165: 25/10/2021 05:20:22 | 25/10/2021 05:20:42: {'loss': [0.09647540003061295], 'acc': [0.9538499712944031], 'val_loss': [0.09657362103462219], 'val_acc': [0.9540150165557861], 'lr': [0.0018855681]}
# Epoch 166: 25/10/2021 05:20:42 | 25/10/2021 05:21:01: {'loss': [0.09709001332521439], 'acc': [0.9536510109901428], 'val_loss': [0.09816542267799377], 'val_acc': [0.9527850151062012], 'lr': [0.0018667125]}
# Epoch 167: 25/10/2021 05:21:01 | 25/10/2021 05:21:21: {'loss': [0.09635720402002335], 'acc': [0.9540380239486694], 'val_loss': [0.09481072425842285], 'val_acc': [0.9545249938964844], 'lr': [0.0018480454]}
# Epoch 168: 25/10/2021 05:21:21 | 25/10/2021 05:21:40: {'loss': [0.09613164514303207], 'acc': [0.9538599848747253], 'val_loss': [0.0942973792552948], 'val_acc': [0.9543700218200684], 'lr': [0.0018295649]}
# Epoch 169: 25/10/2021 05:21:40 | 25/10/2021 05:22:00: {'loss': [0.09628920257091522], 'acc': [0.95415198802948], 'val_loss': [0.09570091962814331], 'val_acc': [0.9542800188064575], 'lr': [0.0018112693]}
# Epoch 170: 25/10/2021 05:22:00 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:22:25: {'loss': [0.09590848535299301], 'acc': [0.9542049765586853], 'val_loss': [0.09419987350702286], 'val_acc': [0.9550999999046326], 'lr': [0.0017931566]}
# Epoch 171: 25/10/2021 05:22:25 | 25/10/2021 05:22:45: {'loss': [0.09532478451728821], 'acc': [0.9543650150299072], 'val_loss': [0.09617786109447479], 'val_acc': [0.9542750120162964], 'lr': [0.001775225]}
# Epoch 172: 25/10/2021 05:22:45 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:23:11: {'loss': [0.09550880640745163], 'acc': [0.9542859792709351], 'val_loss': [0.0932539626955986], 'val_acc': [0.9559100270271301], 'lr': [0.0017574728]}
# Epoch 173: 25/10/2021 05:23:11 | 25/10/2021 05:23:31: {'loss': [0.09591817110776901], 'acc': [0.9540740251541138], 'val_loss': [0.09482280910015106], 'val_acc': [0.9545800089836121], 'lr': [0.001739898]}
# Epoch 174: 25/10/2021 05:23:31 | 25/10/2021 05:23:50: {'loss': [0.09548968821763992], 'acc': [0.9540519714355469], 'val_loss': [0.09401139616966248], 'val_acc': [0.9550049901008606], 'lr': [0.001722499]}
# Epoch 175: 25/10/2021 05:23:50 | 25/10/2021 05:24:09: {'loss': [0.09449993073940277], 'acc': [0.9545689821243286], 'val_loss': [0.0930151492357254], 'val_acc': [0.9558749794960022], 'lr': [0.001705274]}
# Epoch 176: 25/10/2021 05:24:09 | 25/10/2021 05:24:29: {'loss': [0.09452196955680847], 'acc': [0.9546509981155396], 'val_loss': [0.09300641715526581], 'val_acc': [0.9555100202560425], 'lr': [0.0016882212]}
# Epoch 177: 25/10/2021 05:24:29 | 25/10/2021 05:24:48: {'loss': [0.09420517086982727], 'acc': [0.9548379778862], 'val_loss': [0.09424454718828201], 'val_acc': [0.9547299742698669], 'lr': [0.001671339]}
# Epoch 178: 25/10/2021 05:24:48 | 25/10/2021 05:25:08: {'loss': [0.09427515417337418], 'acc': [0.9548850059509277], 'val_loss': [0.09278125315904617], 'val_acc': [0.9552599787712097], 'lr': [0.0016546256]}
# Epoch 179: 25/10/2021 05:25:08 | 25/10/2021 05:25:27: {'loss': [0.09398835897445679], 'acc': [0.9548959732055664], 'val_loss': [0.09237563610076904], 'val_acc': [0.95551997423172], 'lr': [0.0016380794]}
# Epoch 180: 25/10/2021 05:25:27 | 25/10/2021 05:25:47: {'loss': [0.09352967143058777], 'acc': [0.9549980163574219], 'val_loss': [0.09240420907735825], 'val_acc': [0.9556499719619751], 'lr': [0.0016216986]}
# Epoch 181: 25/10/2021 05:25:47 | 25/10/2021 05:26:06: {'loss': [0.09345395863056183], 'acc': [0.9552969932556152], 'val_loss': [0.09255416691303253], 'val_acc': [0.9556750059127808], 'lr': [0.0016054816]}
# Epoch 182: 25/10/2021 05:26:06 | 25/10/2021 05:26:25: {'loss': [0.09334280341863632], 'acc': [0.9553679823875427], 'val_loss': [0.09342078119516373], 'val_acc': [0.9558699727058411], 'lr': [0.0015894268]}
# Epoch 183: 25/10/2021 05:26:25 | 25/10/2021 05:26:45: {'loss': [0.09331542253494263], 'acc': [0.9552739858627319], 'val_loss': [0.09208451211452484], 'val_acc': [0.9557750225067139], 'lr': [0.0015735325]}
# Epoch 184: 25/10/2021 05:26:45 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:27:11: {'loss': [0.09351828694343567], 'acc': [0.9551640152931213], 'val_loss': [0.09083398431539536], 'val_acc': [0.9566850066184998], 'lr': [0.0015577972]}
# Epoch 185: 25/10/2021 05:27:11 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:27:37: {'loss': [0.09248092025518417], 'acc': [0.9556350111961365], 'val_loss': [0.09025938808917999], 'val_acc': [0.9571049809455872], 'lr': [0.0015422192]}
# Epoch 186: 25/10/2021 05:27:37 | 25/10/2021 05:27:58: {'loss': [0.09292655438184738], 'acc': [0.955420970916748], 'val_loss': [0.09274446219205856], 'val_acc': [0.9547100067138672], 'lr': [0.001526797]}
# Epoch 187: 25/10/2021 05:27:58 | 25/10/2021 05:28:18: {'loss': [0.09250470250844955], 'acc': [0.9555619955062866], 'val_loss': [0.09207367897033691], 'val_acc': [0.9553499817848206], 'lr': [0.001511529]}
# Epoch 188: 25/10/2021 05:28:18 | 25/10/2021 05:28:37: {'loss': [0.09234203398227692], 'acc': [0.9556480050086975], 'val_loss': [0.09155311435461044], 'val_acc': [0.9550849795341492], 'lr': [0.0014964137]}
# Epoch 189: 25/10/2021 05:28:37 | 25/10/2021 05:28:57: {'loss': [0.09195341914892197], 'acc': [0.9557449817657471], 'val_loss': [0.09099514037370682], 'val_acc': [0.9565449953079224], 'lr': [0.0014814496]}
# Epoch 190: 25/10/2021 05:28:57 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:29:23: {'loss': [0.09151744842529297], 'acc': [0.9558780193328857], 'val_loss': [0.09069322049617767], 'val_acc': [0.9573000073432922], 'lr': [0.001466635]}
# Epoch 191: 25/10/2021 05:29:23 | 25/10/2021 05:29:43: {'loss': [0.09209895879030228], 'acc': [0.9555220007896423], 'val_loss': [0.09070660173892975], 'val_acc': [0.9557099938392639], 'lr': [0.0014519687]}
# Epoch 192: 25/10/2021 05:29:43 | 25/10/2021 05:30:03: {'loss': [0.09115846455097198], 'acc': [0.956138014793396], 'val_loss': [0.0898989662528038], 'val_acc': [0.9566450119018555], 'lr': [0.001437449]}
# Epoch 193: 25/10/2021 05:30:03 | 25/10/2021 05:30:22: {'loss': [0.09048721194267273], 'acc': [0.9565550088882446], 'val_loss': [0.09081929922103882], 'val_acc': [0.9562900066375732], 'lr': [0.0014230745]}
# Epoch 194: 25/10/2021 05:30:22 | 25/10/2021 05:30:41: {'loss': [0.09110558032989502], 'acc': [0.9561390280723572], 'val_loss': [0.09076381474733353], 'val_acc': [0.9562900066375732], 'lr': [0.0014088438]}
# Epoch 195: 25/10/2021 05:30:41 | 25/10/2021 05:31:01: {'loss': [0.09127632528543472], 'acc': [0.956059992313385], 'val_loss': [0.08963214606046677], 'val_acc': [0.9570800065994263], 'lr': [0.0013947553]}
# Epoch 196: 25/10/2021 05:31:01 | 25/10/2021 05:31:21: {'loss': [0.09032745659351349], 'acc': [0.9565330147743225], 'val_loss': [0.09069236367940903], 'val_acc': [0.9561750292778015], 'lr': [0.0013808077]}
# Epoch 197: 25/10/2021 05:31:21 | 25/10/2021 05:31:40: {'loss': [0.09072709083557129], 'acc': [0.9562219977378845], 'val_loss': [0.08907885104417801], 'val_acc': [0.956974983215332], 'lr': [0.0013669997]}
# Epoch 198: 25/10/2021 05:31:40 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 05:32:06: {'loss': [0.08935492485761642], 'acc': [0.956974983215332], 'val_loss': [0.08865348994731903], 'val_acc': [0.9577699899673462], 'lr': [0.0013533297]}
# Epoch 199: 25/10/2021 05:32:06 | 25/10/2021 05:32:26: {'loss': [0.0901290625333786], 'acc': [0.9568039774894714], 'val_loss': [0.08940741419792175], 'val_acc': [0.9568300247192383], 'lr': [0.0013397965]}
# Epoch 200: 25/10/2021 05:32:26 | 25/10/2021 05:32:45: {'loss': [0.08987606316804886], 'acc': [0.956620991230011], 'val_loss': [0.08992765843868256], 'val_acc': [0.9568250179290771], 'lr': [0.0013263985]}
# Epoch 201: 25/10/2021 05:32:45 | 25/10/2021 05:33:05: {'loss': [0.08987651765346527], 'acc': [0.9566529989242554], 'val_loss': [0.08957353234291077], 'val_acc': [0.9568700194358826], 'lr': [0.0013131344]}
# ...
# Epoch 923: 25/10/2021 09:29:25 | 25/10/2021 09:29:44: {'loss': [0.067429319024086], 'acc': [0.9663950204849243], 'val_loss': [0.06833233684301376], 'val_acc': [0.9662700295448303], 'lr': [9.266588e-07]}
# Epoch 924: 25/10/2021 09:29:44 | 25/10/2021 09:30:03: {'loss': [0.06714881211519241], 'acc': [0.9666069746017456], 'val_loss': [0.06722646206617355], 'val_acc': [0.966385006904602], 'lr': [9.173922e-07]}
# Epoch 925: 25/10/2021 09:30:03 | 25/10/2021 09:30:22: {'loss': [0.06718759983778], 'acc': [0.966687023639679], 'val_loss': [0.06740101426839828], 'val_acc': [0.9663199782371521], 'lr': [9.082183e-07]}
# Epoch 926: 25/10/2021 09:30:22 | 25/10/2021 09:30:40: {'loss': [0.06702698767185211], 'acc': [0.9667540192604065], 'val_loss': [0.0667862668633461], 'val_acc': [0.9669600129127502], 'lr': [8.991361e-07]}
# Epoch 927: 25/10/2021 09:30:40 | 25/10/2021 09:30:59: {'loss': [0.06737078726291656], 'acc': [0.9663320183753967], 'val_loss': [0.0686885416507721], 'val_acc': [0.9657400250434875], 'lr': [8.9014475e-07]}
# Epoch 928: 25/10/2021 09:30:59 | 25/10/2021 09:31:18: {'loss': [0.06713743507862091], 'acc': [0.9664250016212463], 'val_loss': [0.066385917365551], 'val_acc': [0.9665949940681458], 'lr': [8.812433e-07]}
# Epoch 929: 25/10/2021 09:31:18 | 25/10/2021 09:31:37: {'loss': [0.06717455387115479], 'acc': [0.9664869904518127], 'val_loss': [0.06772066652774811], 'val_acc': [0.9659199714660645], 'lr': [8.7243086e-07]}
# Epoch 930: 25/10/2021 09:31:37 | 25/10/2021 09:31:56: {'loss': [0.06735468655824661], 'acc': [0.9665120244026184], 'val_loss': [0.0664931982755661], 'val_acc': [0.9670100212097168], 'lr': [8.6370653e-07]}
# Epoch 931: 25/10/2021 09:31:56 | 25/10/2021 09:32:15: {'loss': [0.06749323010444641], 'acc': [0.9663869738578796], 'val_loss': [0.06687551736831665], 'val_acc': [0.9661300182342529], 'lr': [8.5506946e-07]}
# Epoch 932: 25/10/2021 09:32:15 | 25/10/2021 09:32:34: {'loss': [0.06750026345252991], 'acc': [0.9664520025253296], 'val_loss': [0.06731686741113663], 'val_acc': [0.9660750031471252], 'lr': [8.465188e-07]}
# Epoch 933: 25/10/2021 09:32:34 | 25/10/2021 09:32:56: {'loss': [0.06708582490682602], 'acc': [0.9664450287818909], 'val_loss': [0.06716888397932053], 'val_acc': [0.9665200114250183], 'lr': [8.380536e-07]}
# Epoch 934: 25/10/2021 09:32:56 | 25/10/2021 09:33:15: {'loss': [0.06742717325687408], 'acc': [0.966454029083252], 'val_loss': [0.06841631978750229], 'val_acc': [0.9661049842834473], 'lr': [8.2967307e-07]}
# Epoch 935: 25/10/2021 09:33:15 | 25/10/2021 09:33:34: {'loss': [0.06731142103672028], 'acc': [0.9665849804878235], 'val_loss': [0.06743215769529343], 'val_acc': [0.9664850234985352], 'lr': [8.213763e-07]}
# Epoch 936: 25/10/2021 09:33:34 | 25/10/2021 09:33:53: {'loss': [0.06778626888990402], 'acc': [0.9659370183944702], 'val_loss': [0.06787865608930588], 'val_acc': [0.9658949971199036], 'lr': [8.1316256e-07]}
# Epoch 937: 25/10/2021 09:33:53 | 25/10/2021 09:34:12: {'loss': [0.06751111894845963], 'acc': [0.9663950204849243], 'val_loss': [0.06771622598171234], 'val_acc': [0.9660599827766418], 'lr': [8.0503094e-07]}
# Epoch 938: 25/10/2021 09:34:12 | 25/10/2021 09:34:32: {'loss': [0.06721185892820358], 'acc': [0.9663860201835632], 'val_loss': [0.06718035787343979], 'val_acc': [0.966385006904602], 'lr': [7.969806e-07]}
# Epoch 939: 25/10/2021 09:34:32 | INFO:tensorflow:Assets written to: ../models/deepchess\deepchess\assets
# 25/10/2021 09:34:57: {'loss': [0.06703170388936996], 'acc': [0.9667379856109619], 'val_loss': [0.0659281462430954], 'val_acc': [0.9673900008201599], 'lr': [7.890108e-07]}
# Epoch 940: 25/10/2021 09:34:57 | 25/10/2021 09:35:16: {'loss': [0.0671791061758995], 'acc': [0.9664250016212463], 'val_loss': [0.06859458982944489], 'val_acc': [0.9655349850654602], 'lr': [7.811207e-07]}
# Epoch 941: 25/10/2021 09:35:16 | 25/10/2021 09:35:35: {'loss': [0.06753186136484146], 'acc': [0.9662520289421082], 'val_loss': [0.06699319928884506], 'val_acc': [0.9667199850082397], 'lr': [7.733095e-07]}
# Epoch 942: 25/10/2021 09:35:35 | 25/10/2021 09:35:54: {'loss': [0.06716369837522507], 'acc': [0.9666159749031067], 'val_loss': [0.06708218902349472], 'val_acc': [0.9662899971008301], 'lr': [7.6557643e-07]}
# Epoch 943: 25/10/2021 09:35:54 | 25/10/2021 09:36:13: {'loss': [0.0669984370470047], 'acc': [0.9665470123291016], 'val_loss': [0.06783221662044525], 'val_acc': [0.9659550189971924], 'lr': [7.5792065e-07]}
# Epoch 944: 25/10/2021 09:36:13 | 25/10/2021 09:36:31: {'loss': [0.0671326145529747], 'acc': [0.966625988483429], 'val_loss': [0.06786070764064789], 'val_acc': [0.9661399722099304], 'lr': [7.503414e-07]}
# Epoch 945: 25/10/2021 09:36:31 | 25/10/2021 09:36:50: {'loss': [0.06717684119939804], 'acc': [0.9665070176124573], 'val_loss': [0.06709147244691849], 'val_acc': [0.9665449857711792], 'lr': [7.4283804e-07]}
# Epoch 946: 25/10/2021 09:36:50 | 25/10/2021 09:37:09: {'loss': [0.06761018931865692], 'acc': [0.9662839770317078], 'val_loss': [0.06757743656635284], 'val_acc': [0.9661750197410583], 'lr': [7.354097e-07]}
# Epoch 947: 25/10/2021 09:37:09 | 25/10/2021 09:37:28: {'loss': [0.06786967813968658], 'acc': [0.966081976890564], 'val_loss': [0.06852596253156662], 'val_acc': [0.9657750129699707], 'lr': [7.2805557e-07]}
# Epoch 948: 25/10/2021 09:37:28 | 25/10/2021 09:37:47: {'loss': [0.06713560223579407], 'acc': [0.9664769768714905], 'val_loss': [0.06854335218667984], 'val_acc': [0.9658250212669373], 'lr': [7.20775e-07]}
# Epoch 949: 25/10/2021 09:37:47 | 25/10/2021 09:38:06: {'loss': [0.06719136983156204], 'acc': [0.9666630029678345], 'val_loss': [0.0680457130074501], 'val_acc': [0.966035008430481], 'lr': [7.1356726e-07]}
# Epoch 950: 25/10/2021 09:38:06 | 25/10/2021 09:38:24: {'loss': [0.06727703660726547], 'acc': [0.9664890170097351], 'val_loss': [0.06689510494470596], 'val_acc': [0.9665949940681458], 'lr': [7.064316e-07]}
# Epoch 951: 25/10/2021 09:38:24 | 25/10/2021 09:38:43: {'loss': [0.06734961271286011], 'acc': [0.9664260149002075], 'val_loss': [0.06782251596450806], 'val_acc': [0.9660900235176086], 'lr': [6.9936726e-07]}
# Epoch 952: 25/10/2021 09:38:43 | 25/10/2021 09:39:02: {'loss': [0.06771236658096313], 'acc': [0.9662349820137024], 'val_loss': [0.06844103336334229], 'val_acc': [0.966094970703125], 'lr': [6.923736e-07]}
# Epoch 953: 25/10/2021 09:39:02 | 25/10/2021 09:39:21: {'loss': [0.0673927441239357], 'acc': [0.9664570093154907], 'val_loss': [0.06807408481836319], 'val_acc': [0.9663000106811523], 'lr': [6.8544983e-07]}
# Epoch 954: 25/10/2021 09:39:21 | 25/10/2021 09:39:40: {'loss': [0.06690222024917603], 'acc': [0.966605007648468], 'val_loss': [0.06694906949996948], 'val_acc': [0.9663699865341187], 'lr': [6.785953e-07]}
# Epoch 955: 25/10/2021 09:39:40 | 25/10/2021 09:39:59: {'loss': [0.06702744215726852], 'acc': [0.9665399789810181], 'val_loss': [0.0669073686003685], 'val_acc': [0.9665449857711792], 'lr': [6.7180935e-07]}
# Epoch 956: 25/10/2021 09:39:59 | 25/10/2021 09:40:18: {'loss': [0.06722573935985565], 'acc': [0.9663649797439575], 'val_loss': [0.0668419823050499], 'val_acc': [0.966825008392334], 'lr': [6.6509125e-07]}
# Epoch 957: 25/10/2021 09:40:18 | 25/10/2021 09:40:37: {'loss': [0.06697448343038559], 'acc': [0.966530978679657], 'val_loss': [0.0681326761841774], 'val_acc': [0.9660149812698364], 'lr': [6.5844034e-07]}
# Epoch 958: 25/10/2021 09:40:37 | 25/10/2021 09:40:56: {'loss': [0.06736794859170914], 'acc': [0.9663540124893188], 'val_loss': [0.06733500957489014], 'val_acc': [0.9666000008583069], 'lr': [6.5185594e-07]}
# Epoch 959: 25/10/2021 09:40:56 | 25/10/2021 09:41:14: {'loss': [0.06714731454849243], 'acc': [0.9665499925613403], 'val_loss': [0.0668310895562172], 'val_acc': [0.9669150114059448], 'lr': [6.4533737e-07]}
# Epoch 960: 25/10/2021 09:41:14 | 25/10/2021 09:41:33: {'loss': [0.06731528788805008], 'acc': [0.9663630127906799], 'val_loss': [0.06796784698963165], 'val_acc': [0.9661650061607361], 'lr': [6.38884e-07]}
# Epoch 961: 25/10/2021 09:41:33 | 25/10/2021 09:41:52: {'loss': [0.06717459857463837], 'acc': [0.9664390087127686], 'val_loss': [0.06854765862226486], 'val_acc': [0.9654350280761719], 'lr': [6.3249513e-07]}
# Epoch 962: 25/10/2021 09:41:52 | 25/10/2021 09:42:10: {'loss': [0.06764376908540726], 'acc': [0.9662579894065857], 'val_loss': [0.0674799233675003], 'val_acc': [0.9668049812316895], 'lr': [6.2617016e-07]}
# Epoch 963: 25/10/2021 09:42:10 | 25/10/2021 09:42:29: {'loss': [0.06728367507457733], 'acc': [0.9664750099182129], 'val_loss': [0.06767487525939941], 'val_acc': [0.9663900136947632], 'lr': [6.1990846e-07]}
# Epoch 964: 25/10/2021 09:42:29 | 25/10/2021 09:42:48: {'loss': [0.06702326983213425], 'acc': [0.9664599895477295], 'val_loss': [0.06769237667322159], 'val_acc': [0.9664750099182129], 'lr': [6.137094e-07]}
# Epoch 965: 25/10/2021 09:42:48 | 25/10/2021 09:43:06: {'loss': [0.06679284572601318], 'acc': [0.9668200016021729], 'val_loss': [0.06690073013305664], 'val_acc': [0.9664300084114075], 'lr': [6.075723e-07]}
# Epoch 966: 25/10/2021 09:43:06 | 25/10/2021 09:43:25: {'loss': [0.06734587252140045], 'acc': [0.9665150046348572], 'val_loss': [0.06701580435037613], 'val_acc': [0.966284990310669], 'lr': [6.014966e-07]}
# Epoch 967: 25/10/2021 09:43:25 | 25/10/2021 09:43:44: {'loss': [0.06779956817626953], 'acc': [0.9660789966583252], 'val_loss': [0.06765447556972504], 'val_acc': [0.9665150046348572], 'lr': [5.9548165e-07]}
# Epoch 968: 25/10/2021 09:43:44 | 25/10/2021 09:44:03: {'loss': [0.06718853861093521], 'acc': [0.9664329886436462], 'val_loss': [0.0675172284245491], 'val_acc': [0.9660850167274475], 'lr': [5.8952685e-07]}
# Epoch 969: 25/10/2021 09:44:03 | 25/10/2021 09:44:22: {'loss': [0.06762903928756714], 'acc': [0.9662759900093079], 'val_loss': [0.0681164413690567], 'val_acc': [0.9659000039100647], 'lr': [5.8363156e-07]}
# Epoch 970: 25/10/2021 09:44:22 | 25/10/2021 09:44:40: {'loss': [0.0673174187541008], 'acc': [0.9665200114250183], 'val_loss': [0.06662939488887787], 'val_acc': [0.9668899774551392], 'lr': [5.777952e-07]}
# Epoch 971: 25/10/2021 09:44:40 | 25/10/2021 09:44:58: {'loss': [0.06732810288667679], 'acc': [0.9664480090141296], 'val_loss': [0.06703971326351166], 'val_acc': [0.9663900136947632], 'lr': [5.7201726e-07]}
# Epoch 972: 25/10/2021 09:44:58 | 25/10/2021 09:45:17: {'loss': [0.06713087856769562], 'acc': [0.9665579795837402], 'val_loss': [0.06704531610012054], 'val_acc': [0.9669700264930725], 'lr': [5.662971e-07]}
# Epoch 973: 25/10/2021 09:45:17 | 25/10/2021 09:45:36: {'loss': [0.06760399788618088], 'acc': [0.9660710096359253], 'val_loss': [0.06765249371528625], 'val_acc': [0.966284990310669], 'lr': [5.6063413e-07]}
# Epoch 974: 25/10/2021 09:45:36 | 25/10/2021 09:45:54: {'loss': [0.06740369647741318], 'acc': [0.9664400219917297], 'val_loss': [0.06763992458581924], 'val_acc': [0.96635502576828], 'lr': [5.550278e-07]}
# Epoch 975: 25/10/2021 09:45:54 | 25/10/2021 09:46:14: {'loss': [0.06732633709907532], 'acc': [0.9664310216903687], 'val_loss': [0.06659010797739029], 'val_acc': [0.9667750000953674], 'lr': [5.494775e-07]}
# Epoch 976: 25/10/2021 09:46:14 | 25/10/2021 09:46:33: {'loss': [0.06716108322143555], 'acc': [0.9664369821548462], 'val_loss': [0.06701456755399704], 'val_acc': [0.966729998588562], 'lr': [5.439827e-07]}
# Epoch 977: 25/10/2021 09:46:33 | 25/10/2021 09:46:51: {'loss': [0.06687600910663605], 'acc': [0.9662430286407471], 'val_loss': [0.06735129654407501], 'val_acc': [0.9668750166893005], 'lr': [5.385429e-07]}
# Epoch 978: 25/10/2021 09:46:51 | 25/10/2021 09:47:10: {'loss': [0.06722824275493622], 'acc': [0.9664959907531738], 'val_loss': [0.06774958223104477], 'val_acc': [0.9661650061607361], 'lr': [5.331575e-07]}
# Epoch 979: 25/10/2021 09:47:10 | 25/10/2021 09:47:29: {'loss': [0.06710799783468246], 'acc': [0.9665619730949402], 'val_loss': [0.06835814565420151], 'val_acc': [0.96635502576828], 'lr': [5.2782593e-07]}
# Epoch 980: 25/10/2021 09:47:29 | 25/10/2021 09:47:48: {'loss': [0.06744265556335449], 'acc': [0.9664419889450073], 'val_loss': [0.06738214939832687], 'val_acc': [0.966605007648468], 'lr': [5.225477e-07]}
# Epoch 981: 25/10/2021 09:47:48 | 25/10/2021 09:48:07: {'loss': [0.06715873628854752], 'acc': [0.9666929841041565], 'val_loss': [0.06765642762184143], 'val_acc': [0.9660750031471252], 'lr': [5.173222e-07]}
# Epoch 982: 25/10/2021 09:48:07 | 25/10/2021 09:48:26: {'loss': [0.06736479699611664], 'acc': [0.9664239883422852], 'val_loss': [0.06751956790685654], 'val_acc': [0.9662399888038635], 'lr': [5.12149e-07]}
# Epoch 983: 25/10/2021 09:48:26 | 25/10/2021 09:48:44: {'loss': [0.0670485869050026], 'acc': [0.9664319753646851], 'val_loss': [0.0678774043917656], 'val_acc': [0.9662500023841858], 'lr': [5.070275e-07]}
# Epoch 984: 25/10/2021 09:48:44 | 25/10/2021 09:49:03: {'loss': [0.06729888916015625], 'acc': [0.9663400053977966], 'val_loss': [0.06656009703874588], 'val_acc': [0.9671300053596497], 'lr': [5.0195723e-07]}
# Epoch 985: 25/10/2021 09:49:03 | 25/10/2021 09:49:22: {'loss': [0.06738670915365219], 'acc': [0.9663919806480408], 'val_loss': [0.067681223154068], 'val_acc': [0.9660199880599976], 'lr': [4.969377e-07]}
# Epoch 986: 25/10/2021 09:49:22 | 25/10/2021 09:49:41: {'loss': [0.0672544538974762], 'acc': [0.9664930105209351], 'val_loss': [0.06736283004283905], 'val_acc': [0.9663450121879578], 'lr': [4.919683e-07]}
# Epoch 987: 25/10/2021 09:49:41 | 25/10/2021 09:50:00: {'loss': [0.06721287965774536], 'acc': [0.9665889739990234], 'val_loss': [0.06665787100791931], 'val_acc': [0.9665949940681458], 'lr': [4.870486e-07]}
# Epoch 988: 25/10/2021 09:50:00 | 25/10/2021 09:50:19: {'loss': [0.0671859011054039], 'acc': [0.9666290283203125], 'val_loss': [0.06745100766420364], 'val_acc': [0.966094970703125], 'lr': [4.8217817e-07]}
# Epoch 989: 25/10/2021 09:50:19 | 25/10/2021 09:50:37: {'loss': [0.06754814088344574], 'acc': [0.9663439989089966], 'val_loss': [0.06676582247018814], 'val_acc': [0.96670001745224], 'lr': [4.7735637e-07]}
# Epoch 990: 25/10/2021 09:50:37 | 25/10/2021 09:50:56: {'loss': [0.06709975749254227], 'acc': [0.9664589762687683], 'val_loss': [0.06664092093706131], 'val_acc': [0.9668149948120117], 'lr': [4.725828e-07]}
# Epoch 991: 25/10/2021 09:50:56 | 25/10/2021 09:51:14: {'loss': [0.06749140471220016], 'acc': [0.9664700031280518], 'val_loss': [0.06762851774692535], 'val_acc': [0.9665499925613403], 'lr': [4.6785698e-07]}
# Epoch 992: 25/10/2021 09:51:14 | 25/10/2021 09:51:34: {'loss': [0.06769929081201553], 'acc': [0.9660859704017639], 'val_loss': [0.06811647117137909], 'val_acc': [0.965815007686615], 'lr': [4.631784e-07]}
# Epoch 993: 25/10/2021 09:51:34 | 25/10/2021 09:51:52: {'loss': [0.06744355708360672], 'acc': [0.966480016708374], 'val_loss': [0.06776367872953415], 'val_acc': [0.9657750129699707], 'lr': [4.5854662e-07]}
# Epoch 994: 25/10/2021 09:51:52 | 25/10/2021 09:52:11: {'loss': [0.06728322058916092], 'acc': [0.9664340019226074], 'val_loss': [0.06652723252773285], 'val_acc': [0.9670249819755554], 'lr': [4.5396115e-07]}
# Epoch 995: 25/10/2021 09:52:11 | 25/10/2021 09:52:30: {'loss': [0.0675085261464119], 'acc': [0.9662449955940247], 'val_loss': [0.06642419099807739], 'val_acc': [0.9673050045967102], 'lr': [4.4942155e-07]}
# Epoch 996: 25/10/2021 09:52:30 | 25/10/2021 09:52:48: {'loss': [0.06766275316476822], 'acc': [0.9660660028457642], 'val_loss': [0.06728347390890121], 'val_acc': [0.9660450220108032], 'lr': [4.4492734e-07]}
# Epoch 997: 25/10/2021 09:52:48 | 25/10/2021 09:53:07: {'loss': [0.06718920171260834], 'acc': [0.9664270281791687], 'val_loss': [0.06591539084911346], 'val_acc': [0.967270016670227], 'lr': [4.4047806e-07]}
# Epoch 998: 25/10/2021 09:53:07 | 25/10/2021 09:53:26: {'loss': [0.0672893300652504], 'acc': [0.9665089845657349], 'val_loss': [0.06797320395708084], 'val_acc': [0.9659649729728699], 'lr': [4.360733e-07]}
# Epoch 999: 25/10/2021 09:53:26 | 25/10/2021 09:53:45: {'loss': [0.067551389336586], 'acc': [0.9661049842834473], 'val_loss': [0.06684340536594391], 'val_acc': [0.9667699933052063], 'lr': [4.3171255e-07]}

# %%
deepchess_model.save_weights('../models/deepchess/deepchess_weights')

# %%
import tensorflow as tf
finalmodel = tf.keras.models.load_model('../models/deepchess/deepchess')

# %%
finalmodel.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 773)]  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 773)]  0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, None, 100)    1403402     input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, 200)    0           sequential[0][0]
#                                                                  sequential[1][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, None, 400)    80400       concatenate[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, None, 200)    80200       dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 100)    20100       dense_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, None, 2)      202         dense_7[0][0]
# ==================================================================================================
# Total params: 1,584,304
# Trainable params: 1,584,304
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import random
x = random.sample(list(zip(win, loss)), 5)
x=np.array(x)

# %%
l=[]
r=[]
for item in x:
    l.append(item[0])
    r.append(item[1])
l = np.array(l)
l = l[:, np.newaxis, :]

r = np.array(r)
r = r[:, np.newaxis, :]

l.shape, r.shape
# Out:
# ((5, 1, 773), (5, 1, 773))

# %%
loaded_preds = finalmodel.predict((l,r))
original_preds = deepchess_model.predict((l,r))
